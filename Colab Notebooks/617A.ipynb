# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
place = int(input())
steps = 0

if place >= 5:
  steps = place//5
  if (place%5):
    steps += 1
elif place:
  steps = 1

print(steps)
# Out:
# 0
# 0
