# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ts = int(input())
result = [0]*ts

for t in range(ts):
  candies = int(input())
  if candies % 2: result[t] = candies - (candies/2) - 0.5
  else: result[t] = candies - (candies/2) - 1

for rst in result: print(int(rst))
# Out:
# 6
# 7
# 1
# 2
# 3
# 2000000000
# 763243547
# 3
# 0
# 0
# 1
# 999999999
# 381621773
