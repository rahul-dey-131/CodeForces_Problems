# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = int(input())
hs = list(map(int, input().split()))
maxh = max(hs)
time = hs.index(maxh)
hs.remove(maxh)
hs.insert(0, maxh)
hs.reverse()
time += hs.index(min(hs))
print(time)
# Out:
# 7
# 10 10 58 31 63 40 76
# 10
