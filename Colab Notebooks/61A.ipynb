# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
num1 = input()
num2 = input()
result = ""

for num in range(len(num1)):
  if num1[num] == num2[num]: result += "0"
  else: result += "1"

print(result)
# Out:
# 01110
# 01100
# 00010
