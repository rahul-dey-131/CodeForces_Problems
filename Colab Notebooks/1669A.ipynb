# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ts = int(input())
result = ["Division "]*ts

for t in range(ts):
  rating = int(input())
  if rating >= 1900: result[t] += "1"
  elif rating >= 1600: result[t] += "2"
  elif rating >= 1400: result[t] += "3"
  else: result[t] += "4"

for r in result: print(r)
# Out:
# 7
# -789
# 1299
# 1300
# 1399
# 1400
# 1679
# 2300
# Division 4
# Division 4
# Division 4
# Division 4
# Division 3
# Division 2
# Division 1
