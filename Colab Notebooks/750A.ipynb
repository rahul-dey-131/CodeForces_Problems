# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
[n, k] = list(map(int, input().split()))
timeToSolve = 240 - k
timeTaken, solved = 0, 0

for i in range(1, n+1):
  timeTaken += (5 * i)
  if timeTaken <= timeToSolve: solved += 1
  else: break

print(solved)
# Out:
# 3 222
# 2
