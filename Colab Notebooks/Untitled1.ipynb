# %%
nums = int(input())
exps = []

for n in range(nums):
  inp = input().split("+")
  exps.append(inp)

for exp in exps:
  print(int(exp[0])+int(exp[1]))
# Out:
# 4
# 4+2
# 0+0
# 3+7
# 8+9
# 6
# 0
# 10
# 17

# %%
times = int(input())
results = []

for n in range(times):
  sequence = input()
  word = input()
  initial = sequence.index(word[0])
  time = 0
  for i in range(len(word)):
    if i:
      timeTaken = abs(sequence.index(word[i]) - sequence.index(word[i-1]))
      time += timeTaken
  results.append(time)

for result in results:
  print(result)
# Out:
# 1
# qwertyuiopasdfghjklzxcvbnm
# abacaba
# 74

# %%
tests =  int(input())
reultss = []

for t in range(tests):
  [d, u, v, vf] = map(int, input().split())
  colliTime = d/(u+v)
  reultss.append(colliTime*vf)

for result in reultss:
  print(int(result))
# Out:
# 1
# 28 12 83 19
# 5

# %%
cases = int(input())
teams = int(input())
vars = input().split()
sts = map(int, input().split())
sts.sort(reversed=True)
num0, num1 = [], []

for var in vars:
  if var == "0":
    num0.append(var)
  else:
    num1.append(var)

# %%
# Function to calculate maximum total strength
def max_strength(groups, strengths):
    kuet = []
    ruet = []

    for group, strength in zip(groups, strengths):
        if group == 0:
            kuet.append(strength)
        else:
            ruet.append(strength)

    kuet.sort(reverse=True)
    ruet.sort(reverse=True)

    combined = kuet + ruet
    total_strength = sum(combined)

    doubles = min(len(kuet), len(ruet))
    total_strength += sum(combined[:2*doubles])

    return total_strength

results = []

for _ in range(t):
    n = int(input())
    groups = list(map(int, input().split()))
    strengths = list(map(int, input().split()))
    results.append(max_strength(groups, strengths))

for result in results:
    print(result)
# Out:
# 1
# 4
# 0 1 1 1
# 1 10 100 1000
# 2112
