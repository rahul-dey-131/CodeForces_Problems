# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
inp = input().split()
n, k = int(inp[0]), int(inp[1])

for i in range(k):
  if (n%10): n -= 1
  else: n /= 10

print(int(n)) if int(n)>0 else print(1)
# Out:
# 1000 7
# 1
