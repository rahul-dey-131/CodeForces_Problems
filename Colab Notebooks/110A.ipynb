# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
number = input()
n47 = number.count("4") + number.count("7")
print("YES") if (n47 == 4 or n47 == 7) else print("NO")
# Out:
# 1000000000000000000000
# NO
