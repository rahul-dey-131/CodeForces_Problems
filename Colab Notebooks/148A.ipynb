# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
k = int(input())
l = int(input())
m = int(input())
n = int(input())
d = int(input())
result = d
for i in range(1, d+1):
  if i % k == 0 or i % l == 0 or i % m == 0 or i % n == 0: result -= 1
print(d-result)
# Out:
# 2
# 3
# 4
# 5
# 24
# 17
