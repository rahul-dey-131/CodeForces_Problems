# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ts = int(input())
results = []

for t in range(ts):
    [a, b, c] = list(map(int, input().split()))
    results.append("STAIR" if (a < b and b < c) else "PEAK" if (a < b and b > c) else "NONE")

for result in results: print(result)
# Out:
# STAIR
# NONE
# PEAk
# PEAk
# NONE
# NONE
# STAIR
