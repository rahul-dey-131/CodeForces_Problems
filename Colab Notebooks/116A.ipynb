# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
stops = int(input())
remaining = [0]

for stop in range(stops):
  [exit, enter] = list(map(int, input().split()))
  remaining.append(remaining[-1] + enter - exit)

print(max(remaining))
# Out:
# 4
# 0 3
# 2 5
# 4 2
# 4 0
# 6
