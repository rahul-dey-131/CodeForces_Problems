# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
str1 = input().lower()
str2 = input().lower()
result = 0

for n in range(len(str1)):
  if str1[n] != str2[n]:
    if (str1[n] < str2[n]): result = -1
    else: result = 1
    break

print(result)
# Out:
# abcdefg
# abcdeff
# 1
