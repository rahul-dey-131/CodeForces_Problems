# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
borze = input()
result = ""

i = 0
while i < len(borze):
  if borze[i] == ".":
    result += "0"
    i += 1
  elif borze[i] == "-":
    if borze[i+1] == ".":
      result += "1"
      i += 2
    elif borze[i+1] == "-":
      result += "2"
      i += 2

print(result)
# Out:
# -..-.--
# 1012
