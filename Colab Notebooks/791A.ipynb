# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
weights = input().split()
[wLimak, wBob, year] = [int(weights[0]), int(weights[1]), 0]

while (wLimak <= wBob):
  wLimak *= 3
  wBob *= 2
  year += 1

print(year)
# Out:
# 1 1
# 1
