# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def abbr(word):
  if (len(word) > 10):
    abbrted = word[0] + str(len(word[1:-1])) + word[-1]
    return abbrted
  else:
    return word

n = int(input())
for x in range(n):
  word = input()
  print(abbr(word))
# Out:
# 4
# word
# word
# localization
# l10n
# internationalization
# i18n
# pneumonoultramicroscopicsilicovolcanoconiosis
# p43s
