# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ts = int(input())
results = ["NO"] * ts

for t in range(ts):
    n = int(input())
    A = list(map(int, input().split()))
    if (A[0] % 2 == sum(A[1:]) % 2): results[t] = "YES"

for result in results: print(result)
# Out:
# YES
# NO
# YES
# YES
# NO
# YES
# YES
