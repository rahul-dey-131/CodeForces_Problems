# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ts = int(input())
results = [0] * ts

for t in range(ts):
    [x, y, n] = list(map(int, input().split()))
    if (n % x) >= y: results[t] = (n - (n % x) + y)
    else: results[t] = n - (n % x) - x + y

for result in results: print(result)
# Out:
# 15
