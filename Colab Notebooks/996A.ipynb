# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = int(input())
bills = [100, 20, 10, 5, 1]
result = 0
for bill in bills:
  result += n // bill
  n %= bill
print(result)
# Out:
# 43
# 5
