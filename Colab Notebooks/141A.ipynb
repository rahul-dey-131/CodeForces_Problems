# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
host = input()
guest = input()
letters = list(input())
result = "NO"
total = list(host+guest)

for c in total:
  if c in letters: letters.remove(c)
  else: break

if len(letters) == 0: result = "YES"

print(result)
# Out:
# ALJFAOIDJSOIFJODNFLKASDJFOAJDFJAOIDSJAOIDJFLAJDFLJADJ
# AODSFJALJDFLAJDFLAJLDKFJAOIJDFOADFOIAJDOJALKDFJALDJFOAJOIDFJASLDFLKADFOOFA
# ALJFAOIDJSOIFJODNFLKASDJFOAJDFJAOIDSJAOIDJFLAJDFLJADJAODSFJALJDFLAJDFLAJLDKFJAOIJDFOADFOIAJDOJALKDFJALDJFOAJOIDFJASLDFLKADFOOFA
# YES
