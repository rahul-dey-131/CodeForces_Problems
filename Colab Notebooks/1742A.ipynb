# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ts = int(input())
result = []

for t in range(ts):
  numbers = [a, b, c] = list(map(int, input().split()))
  maxNum = max(a, b, c)
  numbers.remove(maxNum)
  if maxNum == sum(numbers): result.append("YES")
  else: result.append("NO")

for r in result:
  print(r)
# Out:
# 2
# 1 4 3
# 2 5 8
# YES
# NO
