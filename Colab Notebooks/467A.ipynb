# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = int(input())
result = 0

for i in range(n):
  [p, q] = list(map(int, input().split()))
  if (q-p) >= 2: result += 1

print(result)
# Out:
# 3
# 1 10
# 0 10
# 10 10
# 2
