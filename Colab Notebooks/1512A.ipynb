# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ts = int(input())
result = [0] * ts

for t in range(ts):
  ns = int(input())
  A = list(map(int, input().split()))
  for a in A:
    if A.count(a) == 1:
      result[t] = A.index(a) + 1
      break

for r in result: print(r)
# Out:
# 4
# 4
# 11 13 11 11
# 5
# 1 4 4 4 4
# 10
# 3 3 3 3 10 3 3 3 3 3
# 3
# 20 20 10
# 2
# 1
# 5
# 3
