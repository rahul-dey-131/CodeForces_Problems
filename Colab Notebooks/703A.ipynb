# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ns = int(input())
winner = [0, 0]
for n in range(ns):
    [m, c] = map(int, input().split())
    if m > c: winner[0] += 1
    elif c > m: winner[1] += 1

print("Mishka" if winner[0] > winner[1] else "Chris" if winner[0] < winner[1] else "Friendship is magic!^^")
# Out:
# Chris
