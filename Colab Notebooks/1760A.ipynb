# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from statistics import median

ts = int(input())
result = [0] * ts

for t in range(ts):
  nums = list(map(int, input().split()))
  result[t] = median(nums)

for r in result: print(r)
# Out:
# 3
# 5 2 6
# 14 3 4
# 20 2 1
# 5
# 4
# 2
