# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
inp = input()
scores = input()
inpArr = inp.split()
scoresArr = scores.split(" ")
passed = 0
minScore = int(scoresArr[int(inpArr[1])-1])

if len(scoresArr) == int(inpArr[0]):
  for a in scoresArr:
    if int(a)!=0 and int(a)>=minScore: passed += 1

print(passed)
# Out:
# 4 2
# 0 0 0 0
# 0
