# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
drinksVol = int(input()) * 100
drinksOr = sum(list(map(int, input().split())))
print((drinksOr/drinksVol)*100)
# Out:
# 4
# 0  25 50 75
# 37.5
