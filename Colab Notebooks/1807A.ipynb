# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ts = int(input())
result = ["+"] * ts

for t in range(ts):
  [a, b, c] = list(map(int, input().split()))
  if c == a - b: result[t] = "-"

for r in result: print(r)
# Out:
# 3
# 3 4 7
# 1 1 2
# 1 1 0
# +
# +
# -
