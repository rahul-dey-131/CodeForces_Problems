# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
[rs, cs] = list(map(int, input().split()))
for r in range(1, rs+1): print("#"*cs) if (r%2) else print("."*(cs-1) + "#") if (r%4) else print("#" + "."*(cs-1))
# Out:
# 3 3
# ###
# ..#
# ###
