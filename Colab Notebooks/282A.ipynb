# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
times = int(input())
x = 0

for n in range(times):
  operand = input()
  if "++" in operand: x += 1
  elif "--" in operand: x -= 1

print(x)
# Out:
# 2
# x++
# x--
# 0
