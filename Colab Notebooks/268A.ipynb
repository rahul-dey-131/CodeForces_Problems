# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = int(input())
teams, result, serial = [], 0, 0
for i in range(n):
  teams.append(list(map(int, input().split())))
while (serial < n):
  host = teams[serial][0]
  for team in teams:
    if host == team[1]: result += 1
  serial += 1
print(result)
# Out:
# 2
# 1 2
# 1 2
# 0
