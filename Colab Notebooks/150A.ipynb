# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = int(input())
numbers = list(map(int, input().split()))
result, process = 0, [numbers[0]]

for i in range(1, n):
  process.append(numbers[i])
  if numbers.index(max(process)) == i or numbers.index(min(process)) == i: result += 1

print(result)
# Out:
# 10
# 4664 6496 5814 7010 5762 5736 6944 4850 3698 7242
# 4
