# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
numbers = input()
stones = input()
moves = 0

for n in range(int(numbers) - 1):
  if stones[n] == stones[n+1]: moves += 1

print(moves)
# Out:
# 4
# BRBG
# 0
