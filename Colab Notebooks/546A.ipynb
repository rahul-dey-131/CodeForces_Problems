# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
numList = input().split()
k, n, w, cost = int(numList[0]), int(numList[1]), int(numList[2]), 0

for x in range(w): cost += ((x+1) * k)
print(cost-n) if (cost-n >= 0) else print(0)
# Out:
# 2 6 1
# 0
