# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ts = int(input())
results = [0] * ts

for t in range(ts):
    [a, b] = map(int, input().split())
    results[t] = b - a

for r in results: print(r)
# Out:
# 1
# 7
# 0
