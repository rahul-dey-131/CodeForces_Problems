# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ts = int(input())
result = ["YES"]*ts

for t in range(ts):
  n = int(input())
  A = list(map(int, input().split()))
  A.sort()
  for a in range(n-1):
    if abs(A[a]-A[a+1]) > 1:
      result[t] = "NO"
      break

for r in result: print(r)
# Out:
# 5
# 3
# 1 2 2
# 4
# 5 5 5 5
# 3
# 1 2 4
# 4
# 1 2 4 4
# 1
# 100
# YES
# YES
# NO
# NO
# YES
