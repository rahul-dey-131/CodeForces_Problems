# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = int(input())
clauses = ["I love ", "I hate "]
result = ""

for i in range(1, n+1):
  result += clauses[i%2] + "that "

result = result[:-5] + "it"
print(result)
# Out:
# 3
# I hate that I love that I hate it
