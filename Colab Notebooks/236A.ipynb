# %% [markdown]
# (https://))![image.png](data:image/png;base64,...)

# %%
name = list(input())
name = list(dict.fromkeys(name))
print("CHAT WITH HER!") if (len(name)%2==0) else print("IGNORE HIM!")
# Out:
# sevenkplus
# CHAT WITH HET!

# %%
print(dict.fromkeys(name))
# Out:
# {'k': None, 'j': None, 'h': None, 'd': None, 'f': None, 's': None, 'a': None}
