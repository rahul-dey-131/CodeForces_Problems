# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = int(input())
gifts = list(map(int, input().split()))
result = []

for i in range(1, n+1): result.append(gifts.index(i) + 1)
print(" ".join(list(map(str, result))))
# Out:
# 2
# 1 2
# 1 2
