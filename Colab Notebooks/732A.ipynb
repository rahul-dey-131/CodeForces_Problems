# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
[k, r] = list(map(int, input().split()))
bought, checker = 1, k

while True:
  if (str(checker)[-1] == str(r) or str(checker)[-1] == "0"): break
  bought += 1
  checker = k * bought

print(bought)
# Out:
# 237 7
# 1
