# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ts = int(input())
result = []

for t in range(ts):
  ticket = list(map(int, list(input())))
  if sum(ticket[:3]) == sum(ticket[3:]): result.append("YES")
  else: result.append("NO")

for r in result: print(r)
# Out:
# 3
# 045207
# 000000
# 055776
# YES
# YES
# NO
