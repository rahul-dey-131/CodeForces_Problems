# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ns = int(input())
cards = list(map(int, input().split()))
sereja, dima = 0, 0

for n in range(ns):
  maxima = max(cards[0], cards[-1])
  cards.remove(maxima)
  if n % 2: dima += maxima
  else: sereja += maxima

print(sereja, dima)
# Out:
# 7
# 1 2 3 4 5 6 7
# 16 12
