# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ts = int(input())
result = [0] * ts

for t in range(ts):
  n = list(map(int, list(input())))
  result[t] = sum(n)

for r in result: print(r)
# Out:
# 3
# 77
# 21
# 40
# 14
# 3
# 4
