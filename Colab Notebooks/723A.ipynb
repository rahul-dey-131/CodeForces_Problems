# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from statistics import median
Ox = [x1, x2, x3] = list(map(int, input().split()))
avg = median(Ox)
print(int(abs(avg-x1) + abs(avg-x2) + abs(avg-x3)))
# Out:
# 1 100 4
# 99
