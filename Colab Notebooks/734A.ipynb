# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = input()
results = input()
print("Anton") if (results.count("A")>results.count("D")) else print("Danik") if (results.count("A")<results.count("D")) else print("Friendship")
# Out:
# DADADA
# DADADA
# Friendship
