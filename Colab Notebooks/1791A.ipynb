# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ts = int(input())
result = ["NO"] * ts

for t in range(ts):
  ch = input()
  if ch in "codeforces": result[t] = "YES"

for r in result: print(r)
# Out:
# 10
# a
# b
# c
# d
# e
# f
# g
# h
# i
# j
# NO
# NO
# YES
# YES
# YES
# YES
# NO
# NO
# NO
# NO
