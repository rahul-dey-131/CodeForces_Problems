# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
inp = list(map(int, input().split()))
ai = list(map(int, input().split()))
width = 0

for a in ai:
  if (a > inp[1]): width += 2
  else: width += 1

print(width)
# Out:
# 6 5
# 7 6 8 9 10 5
# 11
