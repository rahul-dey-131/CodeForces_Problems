# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def calculating_function(n):
    if n % 2 == 0: return n // 2
    else: return -(n // 2 + 1)

n = int(input())
print(calculating_function(n))
# Out:
# 1000000000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-62484424c7d6> in <cell line: 0>()
#       3
#       4 for i in range(1, n+1):
# ----> 5   result += ((-1)**i)*i
#       6
#       7 print(result)
#
# KeyboardInterrupt:
