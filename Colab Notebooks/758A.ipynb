# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = int(input())
A = list(map(int, input().split()))
maximum, total = max(A), 0
for a in A: total += (maximum - a)
print(total)
# Out:
# 1
# 12
# 0
