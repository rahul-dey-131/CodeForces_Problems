# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ts = int(input())
results, mainS = [0] * ts, "codeforces"

for t in range(ts):
    s = input()
    for i in range(len(s)):
        if s[i] != mainS[i]: results[t] += 1 

for r in results: print(r)
# Out:
# 4
# 5
# 0
# 4
# 9
