# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ts = int(input())
results = []

for t in range(ts):
    n = int(input())
    results.append("First" if (n%3) else "Second")

for result in results:  print(result)
# Out:
# First
# Second
# First
# First
# Second
# First
