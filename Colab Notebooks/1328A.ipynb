# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from math import ceil

ts = int(input())
result = [0]*ts

for t in range(ts):
  [a, b] = list(map(int, input().split()))
  result[t] = (b*(ceil(a/b)))-a

for rst in result:
  print(rst)
# Out:
# 5
# 10 4
# 13 9
# 100 13
# 123 456
# 92 46
# 2
# 5
# 4
# 333
# 0
