# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ts = int(input())
results = [0] * ts

for t in range(ts): 
    n = int(input())
    results[t] = n//2
    
for result in results: print(result)
# Out:
# 1
# 2
