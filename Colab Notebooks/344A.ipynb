# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
nums = int(input())
magnetRow = []
result = 0

for num in range(nums):
  magnetRow.append(input())

for n in range(len(magnetRow) - 1):
  if magnetRow[n] == magnetRow[n + 1]: continue
  else: result += 1

print(result+1)
# Out:
# 4
# 01
# 01
# 10
# 10
# 2
