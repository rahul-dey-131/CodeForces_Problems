# %% [markdown]
# ![image.png](attachment:image.png)

# %%
[n, m] = list(map(int, input().split()))
tester = n + 1

while True:
    if tester == 2 or tester == 3 or tester == 5 or tester == 7: break
    elif (tester % 2) and (tester % 3) and (tester % 5) and (tester % 7): break
    else: tester += 1

print("YES" if tester == m else "NO")
# Out:
# NO
