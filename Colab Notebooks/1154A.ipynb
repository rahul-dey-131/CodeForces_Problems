# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
nums = list(map(int, input().split()))
total = max(nums)
nums.remove(total)
sol = [a, b, c] = [total-nums[0], total-nums[1], total-nums[2]]
print(" ".join(map(str, sol)))
# Out:
# 201 101 101 200
# 100 100 1
