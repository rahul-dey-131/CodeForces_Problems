# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from math import ceil

ts = int(input())
result = [0]*ts

for t in range(ts):
  [a, b] = list(map(int, input().split()))
  result[t] = ceil(abs(a-b)/10)

for r in result: print(r)
# Out:
# 6
# 5 5
# 13 42
# 18 4
# 1337 420
# 123456789 1000000000
# 100500 9000
# 0
# 3
# 2
# 92
# 87654322
# 9150
