# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ts = int(input())
results = [0]*ts

for t in range(ts):
  dists = list(map(int, input().split()))
  for d in dists:
    if d > dists[0]: results[t] += 1

for r in results: print(r)
# Out:
# 2
# 500 600 400 300
# 0 9999 10000 9998
# 1
# 3
