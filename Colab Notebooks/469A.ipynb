# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
n = int(input())
X = set(input().split()[1:])
Y = set(input().split()[1:])
tog = X|Y
if "0" in tog: tog.remove("0")
print("I become the guy.") if len(tog)==n else print("Oh, my keyboard!")
# Out:
# 4
# 3 1 2 3
# 2 2 4
# I become the guy.
