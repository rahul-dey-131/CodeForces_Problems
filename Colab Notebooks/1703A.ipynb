# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ts = int(input())
result = []

for t in range(ts):
  s = input()
  if s.upper() == "YES": result.append("YES")
  else: result.append("NO")

for r in result: print(r)
# Out:
# 10
# YES
# yES
# yes
# Yes
# YeS
# Noo
# orZ
# yEz
# Yas
# XES
# YES
# YES
# YES
# YES
# YES
# NO
# NO
# NO
# NO
# NO
