# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **SOLVE**

# %%
def check(list):
  res = list.count("1")
  if res>=2: return 1
  else: return 0

n = int(input())
result = 0

for x in range(n):
  list = input()
  list.split()
  result += check(list)

print(result)
# Out:
# 2
# 1 0 0
# 0 1 1
# 1

# %% [markdown]
# Testing for Split function

# %%
print("ksdjf dfjds sdlkj".split())
# Out:
# ['ksdjf', 'dfjds', 'sdlkj']
